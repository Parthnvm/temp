# %%
import pandas as pd

# %%
s1 = pd.Series((71, 86, 23, 54,67,99))

# %%
print(s)
# Out:
# 0    71
# 1    86
# 2    23
# 3    54
# 4    67
# 5    99
# dtype: int64

# %%
s2 = pd.Series([71, 86, 23, 54,67,99], index= ["Harry","rayray","dawg","parth","mom","mia"])

# %%
print(s2)
# Out:
# Harry     71
# rayray    86
# dawg      23
# parth     54
# mom       67
# mia       99
# dtype: int64

# %%
s2["Harry"]
# Out:
# np.int64(71)

# %%
s2["mia"]
# Out:
# np.int64(99)
